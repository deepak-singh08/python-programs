# %% [markdown]
# <a href="https://colab.research.google.com/github/deepak-singh08/python-programs/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input("inter no.")
b=input("enter no.2:")
print (a+b)
# Out:
# inter no.12
# enter no.2:12
# 1212

# %% [markdown]
# addition code

# %%
a=int(input("enter number"))
b=int(input("entersecond number"))
print(a+b)
print(type(a))
# Out:
# enter number12
# entersecond number12
# 24
# <class 'int'>

# %%
a=10
print(type(a))
a="ishan"
print(a)
print(type(a))
a=24+24
print (a)
print (type(a))
# Out:
# <class 'int'>
# ishan
# <class 'str'>
# 48
# <class 'int'>

# %% [markdown]
# arithmetic operators

# %%
a=int (input("enter a no."))
b=int (input('enter a second no.'))
print("sum is:", a+b)
print("sub is:", a-b)
print("mul is:", a*b)
print("div is:",a/b)
print("modulus",a%b)
print("power is:",a**b)
# Out:
# enter a no.1
# enter a second no.2
# sum is: 3
# sub is: -1
# mul is: 2
# div is: 0.5
# modulus 1
# power is: 1

# %% [markdown]
# logical operators

# %%
x=int (input("enter a no."))
y=int (input('enter a second no.'))
print("equal to", x==y)
print("not equal to", x!=y)
print("x is greater", x>y)
print("x is smaller",x<y)
print("is greater or equal to", x>=y)
print("is smaller or equal to", x<=y)
# Out:
# enter a no.1
# enter a second no.2
# equal to False
# not equal to True
# x is greater False
# x is smaller True
# is greater or equal to False
# is smaller or equal to True

# %% [markdown]
# assignment operator

# %%
a=int(input("enter a no."))
a+=5
print ("a+=:",a)
a=int(input("enter a no."))
a-=5
print ("a-=:",a)
a=int(input("enter a no."))
a*=5
print ("a*=:",a)
# Out:
# enter a no.1
# a+=: 6
# enter a no.12
# a-=: 7
# enter a no.12
# a*=: 60

# %% [markdown]
# string

# %%
name="archana"
city="chandigarh"
print(name)
print(city)
print(type(name))
print(type(city))
# Out:
# archana
# chandigarh
# <class 'str'>
# <class 'str'>

# %% [markdown]
# multi comma string

# %%
a='''
hey! i am a boy
i am singer
'''
print(a)
print(type(a))
# Out:
# hey! i am a boy
# i am singer
#
# <class 'str'>

# %% [markdown]
# indexing

# %%
text="sunstone"
print(text[0])
print(text[1])
print(text[2])
print(text[5])
print(text[-1])
# Out:
# s
# u
# n
# o
# e

# %% [markdown]
# string slicing

# %%
txt="welcome to rayat bahra university"
print(txt[0:7])
print(txt[10:15])
print(txt[:10])
print(txt[-8:-1])
print(txt[-1:])
print(txt[-9:-4])
print(txt[2:5])
# Out:
# welcome
#  raya
# welcome to
# iversit
# y
# niver
# lco

# %% [markdown]
# triple slicing

# %%
txt="welcome"
print(txt[1:5:2])
print(txt[::2])
print(txt[::-1])
print(txt[2:5:2])
print(txt[1:6:2])
print(txt[2:5:2])
print(txt[2:5:1])
print(txt[2:5:3])
# Out:
# ec
# wloe
# emoclew
# lo
# ecm
# lo
# lco
# l

# %% [markdown]
# lowercase string convergen

# %%
txt="DEEPAK LOVE CHUDAILLL"

print(txt.lower())
print(txt.upper())

print(txt.capitalize()
      )
print(txt.title())
# Out:
# deepak love chudailll
# DEEPAK LOVE CHUDAILLL
# Deepak love chudailll
# Deepak Love Chudailll

# %% [markdown]
# string 1st latter capitalization

# %%
str="hello i am deepak singh"
print(str.title())
# Out:
# Hello I Am Deepak Singh

# %%
str="hello i am deepak singh"
print(str.capitalize())
# Out:
# Hello i am deepak singh

# %%
str="      hello i am deepak singh"

# %% [markdown]
# array list print marks of student

# %%
marks =[ 95, 80, 15, 50, 60, 70, 70, 15, 18, 99]
print (marks)
names =["aman", "deepak", " sahil", "harshita", "nikhil", "sagar", "saksham","shivansh", "muskan", " chudaill"]
print (names)
# Out:
# [95, 80, 15, 50, 60, 70, 70, 15, 18, 99]
# ['aman', 'deepak', ' sahil', 'harshita', 'nikhil', 'sagar', 'saksham', 'shivansh', 'muskan', ' chudaill']

# %% [markdown]
# mixed by using index no

# %%
mixed1 =[100, "Deepak singh", 4.2, "school"]

mixed1[1]="deeeepak"
print(mixed1)
# Out:
# [100, 'deeeepak', 4.2, 'school']

# %%
mixed2 =[110, "Deepak singh", 4.4, "schol"]

mixed2[1]="deeeepak"
print(mixed2)
# Out:
# [110, 'deeeepak', 4.4, 'schol']

# %%
mixed1.append(100)
print(mixed1)
# Out:
# [100, 'deeeepak', 4.2, 'school', 100]
